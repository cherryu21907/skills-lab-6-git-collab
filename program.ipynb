# %%
name = input("What is your name? ")
something = float(input("Input a random number "))

something = something * 1.23

print(name + " your number has been transformed into " + str(something))
# Out:
# What is your name?  1
# Input a random number  1005452.26545
# 1 your number has been transformed into 1236706.2865034998
